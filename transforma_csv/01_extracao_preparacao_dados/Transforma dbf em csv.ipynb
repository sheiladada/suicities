# %% [markdown]
# Arquivo dbf2dbc que foi adquirido no site do datasus (http://www2.datasus.gov.br/DATASUS/index.php?area=060805&item=3)

# %% [markdown]
# # Faz a importacao automatica

# %%
import glob
import os
from simpledbf import Dbf5
import urllib.request
import pandas as pd

# %%
os.system('dbf2dbc ' + file + '.dbc')

# %%
for file in files:
    os.system('dbf2dbc ' + file + '.dbc')
    #os.system('del /f ' + file + '.dbc')

# %%
dbf = Dbf5('BR_Localidades_2010_v1' + '.dbf', codec='latin-1')

# %%
dbf.to_csv('BR_Localidades_2010_v1' + '.csv')

# %%
df = pd.read_csv('BR_Localidades_2010_v1.csv', header = 0, low_memory=False, index_col=0, encoding='latin-1')

# %%
df.head()
# Out:
#          CD_GEOCODI    TIPO    CD_GEOCODB NM_BAIRRO   CD_GEOCODS NM_SUBDIST  \
# ID
# 1   110001505000001  URBANO  1.100015e+11   Redondo  11000150500        NaN
# 2   110001515000001  URBANO           NaN       NaN  11000151500        NaN
# 3   110001520000001  URBANO           NaN       NaN  11000152000        NaN
# 4   110001525000001  URBANO           NaN       NaN  11000152500        NaN
# 5   110001530000001  URBANO           NaN       NaN  11000153000        NaN
#
#     CD_GEOCODD                 NM_DISTRIT  CD_GEOCODM             NM_MUNICIP  \
# ID
# 1    110001505      ALTA FLORESTA D'OESTE     1100015  ALTA FLORESTA D'OESTE
# 2    110001515         FILADÉLFIA D'OESTE     1100015  ALTA FLORESTA D'OESTE
# 3    110001520                IZIDOLÂNDIA     1100015  ALTA FLORESTA D'OESTE
# 4    110001525         NOVA GEASE D'OESTE     1100015  ALTA FLORESTA D'OESTE
# 5    110001530  ROLIM DE MOURA DO GUAPORÉ     1100015  ALTA FLORESTA D'OESTE
#
# ...

# %%
dbf = Dbf5('tb_municip' + '.dbf', codec='latin-1')

# %%
dbf.to_csv('tb_municip' + '.csv')

# %%
df = pd.read_csv('tb_municip.csv', header = 0, low_memory=False, index_col=0, encoding='latin-1')

# %%
df.head()
# Out:
#             CO_MUNICDV CO_STATUS CO_TIPO                  DS_NOME  \
# CO_MUNICIP
# 0                    0     IGNOR   IGNOR     Ignorado ou exterior
# 110000         1100000     IGNOR   IGNOR  Município ignorado - RO
# 110001         1100015     ATIVO   MUNIC    Alta Floresta D'Oeste
# 110002         1100023     ATIVO   MUNIC                Ariquemes
# 110003         1100031     ATIVO   MUNIC                   Cabixi
#
#                          DS_NOMEPAD DS_OBSERV                      CO_ALTER  \
# CO_MUNICIP
# 0              IGNORADO OU EXTERIOR  Ignorado  ,      ,000001-009999,999999
# 110000      MUNICIPIO IGNORADO - RO       NaN                       ,119999
# 110001        ALTA FLORESTA D'OESTE       NaN                           NaN
# 110002                    ARIQUEMES       NaN                           NaN
# 110003                       CABIXI       NaN                           NaN
#
#                                   CO_ALTERDV  CO_REGIAO  CO_UF  ...  \
# ...

# %%
df.iloc[0]
# Out:
# CO_MUNICDV                                   0
# CO_STATUS                                IGNOR
# CO_TIPO                                  IGNOR
# DS_NOME                   Ignorado ou exterior
# DS_NOMEPAD                IGNORADO OU EXTERIOR
# DS_OBSERV                             Ignorado
# CO_ALTER          ,      ,000001-009999,999999
# CO_ALTERDV    ,       ,0000001-0099999,9999999
# CO_REGIAO                                    0
# CO_UF                                        0
# IN_CAPITAL                                 NaN
# IN_AMAZLEG                                   N
# IN_SEMIAR                                    N
# IN_FRONTZN                                   N
# IN_FRONTFX                                   N
# IN_POBREZA                                 NaN
# DT_INSTAL                                  NaN
# DT_EXTIN                                   NaN
# CO_SUCESS                                  NaN
# NU_ORDEM                                     8
# ...

# %%
df.loc[355030]
# Out:
# CO_MUNICDV             3550308
# CO_STATUS                ATIVO
# CO_TIPO                  MUNIC
# DS_NOME              São Paulo
# DS_NOMEPAD           SAO PAULO
# DS_OBSERV                  NaN
# CO_ALTER        ,358001-358058
# CO_ALTERDV    ,3580016-3580586
# CO_REGIAO                    3
# CO_UF                       35
# IN_CAPITAL                   E
# IN_AMAZLEG                   N
# IN_SEMIAR                    N
# IN_FRONTZN                   N
# IN_FRONTFX                   N
# IN_POBREZA                   N
# DT_INSTAL                 1554
# DT_EXTIN                   NaN
# CO_SUCESS                  NaN
# NU_ORDEM                     1
# NU_ORDMAP                    1
# NU_LATITUD            -23.5674
# NU_LONGIT             -46.5704
# NU_ALTITUD                 784
# NU_AREA                1521.11
# Name: 355030, dtype: object
